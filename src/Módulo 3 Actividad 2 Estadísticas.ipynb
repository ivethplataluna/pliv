# %%
import pandas as pd

# %%
crimen = pd.read_csv('crime.csv')

# %%
crimen.head(16421)
# Out:
#          State   Type of Crime                                 Crime  Year  \
# 0      Alabama   Violent Crime  Murder and nonnegligent Manslaughter  1960
# 1      Alabama   Violent Crime  Murder and nonnegligent Manslaughter  1961
# 2      Alabama   Violent Crime  Murder and nonnegligent Manslaughter  1962
# 3      Alabama   Violent Crime  Murder and nonnegligent Manslaughter  1963
# 4      Alabama   Violent Crime  Murder and nonnegligent Manslaughter  1964
# ...        ...             ...                                   ...   ...
# 16416  Wyoming  Property Crime                   Motor vehicle theft  2000
# 16417  Wyoming  Property Crime                   Motor vehicle theft  2001
# 16418  Wyoming  Property Crime                   Motor vehicle theft  2002
# 16419  Wyoming  Property Crime                   Motor vehicle theft  2003
# 16420  Wyoming  Property Crime                   Motor vehicle theft  2004
#
#        Count
# 0        406
# 1        427
# 2        316
# ...

# %%
crimen.describe()
# Out:
#                Year          Count
# count  16422.000000   16422.000000
# mean    1982.500000   29605.496164
# std       13.276322   74399.826883
# min     1960.000000       0.000000
# 25%     1971.000000     669.000000
# 50%     1982.500000    4620.000000
# 75%     1994.000000   24114.000000
# max     2005.000000  986120.000000

# %%
crimen.State.describe()
# Out:
# count       16422
# unique         51
# top       Alabama
# freq          322
# Name: State, dtype: object

# %%
crimen.Crime.describe()
# Out:
# count                                    16422
# unique                                       7
# top       Murder and nonnegligent Manslaughter
# freq                                      2346
# Name: Crime, dtype: object

# %%
crimen.Year.describe()
# Out:
# count    16422.000000
# mean      1982.500000
# std         13.276322
# min       1960.000000
# 25%       1971.000000
# 50%       1982.500000
# 75%       1994.000000
# max       2005.000000
# Name: Year, dtype: float64

# %%
# Gráfica del histograma
crimen.Year.hist();

# %%
# box plot
crimen.boxplot(column='Year');

# %%
import seaborn as sns
import numpy as np

# %%
crimen = pd.read_csv('crime.csv')
sns.set(color_codes = True)
sns.set_theme(style="darkgrid")

# %%
# dropna() devuelve una serie sin
# valores nulos en el campo Age
yearv = crimen.Year.dropna()
sns.histplot(yearv, kde=True);

# %%
crimenv = crimen[["State", "Year", "Count"]]
crimenv.head()
# Out:
#      State  Year  Count
# 0  Alabama  1960    406
# 1  Alabama  1961    427
# 2  Alabama  1962    316
# 3  Alabama  1963    340
# 4  Alabama  1964    316

# %%
sns.boxplot(data=crimen, x='Count', y='Type of Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Type of Crime'>

# %%
sns.boxplot(data=crimen, x='Count', y='Type of Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Type of Crime'>

# %%
sns.boxplot(data=crimen, x='Count', y='Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Crime'>

# %%
sns.boxplot(data=crimen, x='Count', y='State')
# Out:
# <Axes: xlabel='Count', ylabel='State'>

# %%
crimen.Crime.describe()
# Out:
# count                                    16422
# unique                                       7
# top       Murder and nonnegligent Manslaughter
# freq                                      2346
# Name: Crime, dtype: object

# %%
listatipocrimen = crimen[["Type of Crime"]]
listatipocrimen.head(1000)
# Out:
#      Type of Crime
# 0    Violent Crime
# 1    Violent Crime
# 2    Violent Crime
# 3    Violent Crime
# 4    Violent Crime
# ..             ...
# 995  Violent Crime
# 996  Violent Crime
# 997  Violent Crime
# 998  Violent Crime
# 999  Violent Crime
#
# [1000 rows x 1 columns]

# %%
listaestado = crimen[["State"]]
listaestado.head(1000)
# Out:
#         State
# 0     Alabama
# 1     Alabama
# 2     Alabama
# 3     Alabama
# 4     Alabama
# ..        ...
# 995  Arkansas
# 996  Arkansas
# 997  Arkansas
# 998  Arkansas
# 999  Arkansas
#
# [1000 rows x 1 columns]

# %%
listacrimen = crimen[["Crime"]]
listacrimen.head(1000)
# Out:
#                                     Crime
# 0    Murder and nonnegligent Manslaughter
# 1    Murder and nonnegligent Manslaughter
# 2    Murder and nonnegligent Manslaughter
# 3    Murder and nonnegligent Manslaughter
# 4    Murder and nonnegligent Manslaughter
# ..                                    ...
# 995  Murder and nonnegligent Manslaughter
# 996  Murder and nonnegligent Manslaughter
# 997  Murder and nonnegligent Manslaughter
# 998  Murder and nonnegligent Manslaughter
# 999  Murder and nonnegligent Manslaughter
#
# [1000 rows x 1 columns]

# %%
listacrimen = crimen[["Crime"]]
listacrimen.head(1000)
# Out:
#                                     Crime
# 0    Murder and nonnegligent Manslaughter
# 1    Murder and nonnegligent Manslaughter
# 2    Murder and nonnegligent Manslaughter
# 3    Murder and nonnegligent Manslaughter
# 4    Murder and nonnegligent Manslaughter
# ..                                    ...
# 995  Murder and nonnegligent Manslaughter
# 996  Murder and nonnegligent Manslaughter
# 997  Murder and nonnegligent Manslaughter
# 998  Murder and nonnegligent Manslaughter
# 999  Murder and nonnegligent Manslaughter
#
# [1000 rows x 1 columns]

# %%
listaaños = crimen[[ "Count"]]
listaaños.head(1000)
# Out:
#      Count
# 0      406
# 1      427
# 2      316
# 3      340
# 4      316
# ..     ...
# 995    203
# 996    241
# 997    264
# 998    259
# 999    247
#
# [1000 rows x 1 columns]

# %%
# Notación equivalenete a la anterior
crimen['Count'].describe()
# Out:
# count     16422.000000
# mean      29605.496164
# std       74399.826883
# min           0.000000
# 25%         669.000000
# 50%        4620.000000
# 75%       24114.000000
# max      986120.000000
# Name: Count, dtype: float64

# %%
# Notación equivalenete a la anterior
crimen['State'].describe()
# Out:
# count       16422
# unique         51
# top       Alabama
# freq          322
# Name: State, dtype: object

# %%
# Notación equivalenete a la anterior
crimen['Type of Crime'].describe()
# Out:
# count             16422
# unique                2
# top       Violent Crime
# freq               9384
# Name: Type of Crime, dtype: object

# %%
# Calculo de la media
crimen[['Count']].median(axis=0, skipna=True, numeric_only=False)
# Out:
# Count    4620.0
# dtype: float64

# %%
listaaños = crimen[["Year"]]
listaaños.head(10)
# Out:
#    Year
# 0  1960
# 1  1961
# 2  1962
# 3  1963
# 4  1964
# 5  1965
# 6  1966
# 7  1967
# 8  1968
# 9  1969

# %%
listaaños.tail(10)
# Out:
#        Year
# 16412  1996
# 16413  1997
# 16414  1998
# 16415  1999
# 16416  2000
# 16417  2001
# 16418  2002
# 16419  2003
# 16420  2004
# 16421  2005

# %%
listacount = crimen[["Count"]]
listacount.head(10)
# Out:
#      Count
# 0      406
# 1      427
# 2      316
# 3      340
# 4      316
# ..     ...
# 995    203
# 996    241
# 997    264
# 998    259
# 999    247
#
# [1000 rows x 1 columns]

# %%
listacount.tail(10)
# Out:
#        Count
# 16412    669
# 16413    647
# 16414    669
# 16415    596
# 16416    573
# 16417    696
# 16418    743
# 16419    798
# 16420    799
# 16421    739

# %%
# crea un diccionario
dates_dic = {'Year': listaaños, 'Crime':listacrimen, 
     'Type of Crime': listatipocrimen, 
     'Count': listacount}

# %%
dates_dic
# Out:
# {'Year':        Year
#  0      1960
#  1      1961
#  2      1962
#  3      1963
#  4      1964
#  ...     ...
#  16417  2001
#  16418  2002
#  16419  2003
#  16420  2004
#  16421  2005
#
#  [16422 rows x 1 columns],
#  'Crime':                                       Crime
#  0      Murder and nonnegligent Manslaughter
#  1      Murder and nonnegligent Manslaughter
#  2      Murder and nonnegligent Manslaughter
#  3      Murder and nonnegligent Manslaughter
#  4      Murder and nonnegligent Manslaughter
#  ...                                     ...
#  16417                   Motor vehicle theft
#  16418                   Motor vehicle theft
#  16419                   Motor vehicle theft
#  16420                   Motor vehicle theft
#  16421                   Motor vehicle theft
#
#  [16422 rows x 1 columns],
#  'Type of Crime':         Type of Crime
#  0       Violent Crime
#  1       Violent Crime
#  2       Violent Crime
#  3       Violent Crime
#  4       Violent Crime
# ...

# %%
listacampos = crimen[["Year","Type of Crime", "Crime","State","Count"]]
listacampos.head(10)
# Out:
#    Year  Type of Crime                                 Crime    State  Count
# 0  1960  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    406
# 1  1961  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    427
# 2  1962  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 3  1963  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    340
# 4  1964  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 5  1965  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    395
# 6  1966  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    384
# 7  1967  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    415
# 8  1968  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    421
# 9  1969  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    485

# %%
listacampos.tail(10)
# Out:
#        Year   Type of Crime                Crime    State  Count
# 16412  1996  Property Crime  Motor vehicle theft  Wyoming    669
# 16413  1997  Property Crime  Motor vehicle theft  Wyoming    647
# 16414  1998  Property Crime  Motor vehicle theft  Wyoming    669
# 16415  1999  Property Crime  Motor vehicle theft  Wyoming    596
# 16416  2000  Property Crime  Motor vehicle theft  Wyoming    573
# 16417  2001  Property Crime  Motor vehicle theft  Wyoming    696
# 16418  2002  Property Crime  Motor vehicle theft  Wyoming    743
# 16419  2003  Property Crime  Motor vehicle theft  Wyoming    798
# 16420  2004  Property Crime  Motor vehicle theft  Wyoming    799
# 16421  2005  Property Crime  Motor vehicle theft  Wyoming    739

# %%
crimenes = pd.DataFrame(listacampos)
crimenes
# Out:
#        Year   Type of Crime                                 Crime    State  \
# 0      1960   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# 1      1961   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# 2      1962   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# 3      1963   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# 4      1964   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# ...     ...             ...                                   ...      ...
# 16417  2001  Property Crime                   Motor vehicle theft  Wyoming
# 16418  2002  Property Crime                   Motor vehicle theft  Wyoming
# 16419  2003  Property Crime                   Motor vehicle theft  Wyoming
# 16420  2004  Property Crime                   Motor vehicle theft  Wyoming
# 16421  2005  Property Crime                   Motor vehicle theft  Wyoming
#
#        Count
# 0        406
# 1        427
# 2        316
# ...

# %%
crimenes.State.value_counts()
# Out:
# Alabama                 322
# Pennsylvania            322
# Nevada                  322
# New Hampshire           322
# New Jersey              322
# New Mexico              322
# New York                322
# North Carolina          322
# North Dakota            322
# Ohio                    322
# Oaklahoma               322
# Oregon                  322
# Rhode Island            322
# Montana                 322
# South Carolina          322
# South Dakota            322
# Tennessee               322
# Texas                   322
# Utah                    322
# Vermont                 322
# Virginia                322
# Washington              322
# West Virginia           322
# Wisconsin               322
# Nebraska                322
# Missouri                322
# Alaska                  322
# Idaho                   322
# Arizona                 322
# Arkansas                322
# California              322
# Colorado                322
# Connecticut             322
# ...

# %%
crimenes.Crime.value_counts()
# Out:
# Murder and nonnegligent Manslaughter    2346
# Forcible rape                           2346
# Robbery                                 2346
# Aggravated assault                      2346
# Burglary                                2346
# Larceny-theft                           2346
# Motor vehicle theft                     2346
# Name: Crime, dtype: int64

# %%
crimenes.Year.value_counts()
# Out:
# 1960    357
# 1994    357
# 1985    357
# 1986    357
# 1987    357
# 1988    357
# 1989    357
# 1990    357
# 1991    357
# 1992    357
# 1993    357
# 1995    357
# 1961    357
# 1996    357
# 1997    357
# 1998    357
# 1999    357
# 2000    357
# 2001    357
# 2002    357
# 2003    357
# 2004    357
# 1984    357
# 1983    357
# 1982    357
# 1981    357
# 1962    357
# 1963    357
# 1964    357
# 1965    357
# 1966    357
# 1967    357
# 1968    357
# 1969    357
# 1970    357
# 1971    357
# 1972    357
# 1973    357
# 1974    357
# 1975    357
# 1976    357
# 1977    357
# 1978    357
# 1979    357
# 1980    357
# 2005    357
# Name: Year, dtype: int64

# %%
crimenes.Count.value_counts()
# Out:
# 0       35
# 25      28
# 18      26
# 33      25
# 30      25
#         ..
# 4263     1
# 4595     1
# 3818     1
# 3862     1
# 679      1
# Name: Count, Length: 10658, dtype: int64

# %%
# usar el criterio para extraer solo los crimenes de 2005
yr2005 = crimenes[crimenes.Year == 2005]
sns.boxplot(data=yr2005, x='Count', y='Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Crime'>

# %%
yr2005.head(10)
# Out:
#      Year   Type of Crime                                 Crime    State  \
# 45   2005   Violent Crime  Murder and nonnegligent Manslaughter  Alabama
# 91   2005   Violent Crime                         Forcible rape  Alabama
# 137  2005   Violent Crime                               Robbery  Alabama
# 183  2005   Violent Crime                    Aggravated assault  Alabama
# 229  2005  Property Crime                              Burglary  Alabama
# 275  2005  Property Crime                         Larceny-theft  Alabama
# 321  2005  Property Crime                   Motor vehicle theft  Alabama
# 367  2005   Violent Crime  Murder and nonnegligent Manslaughter   Alaska
# 413  2005   Violent Crime                         Forcible rape   Alaska
# 459  2005   Violent Crime                               Robbery   Alaska
#
#       Count
# 45      374
# 91     1564
# 137    6447
# 183   11293
# 229   43473
# 275  120780
# 321   13140
# 367      32
# 413     538
# 459     537

# %%
sns.boxplot(data=yr2005, x='Count', y='Type of Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Type of Crime'>

# %%
yr1960 = crimenes[crimenes.Year == 1960]
sns.boxplot(data=yr1960, x='Count', y='Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Crime'>

# %%
yr1960 = crimenes[crimenes.Year == 1960]
yr1960.head(10)
sns.boxplot(data=yr1960, x='Count', y='Type of Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Type of Crime'>

# %%
# usar el criterio para extraer solo crimenes del estado de Alaska
st = crimenes[crimenes.State == "Alaska"]
sns.boxplot(data=st, x='Count', y='Crime')
# Out:
# <Axes: xlabel='Count', ylabel='Crime'>

# %%
st.head(10)
# Out:
#      Year  Type of Crime                                 Crime   State  Count
# 322  1960  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     23
# 323  1961  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     27
# 324  1962  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     11
# 325  1963  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     16
# 326  1964  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     26
# 327  1965  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     16
# 328  1966  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     35
# 329  1967  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     26
# 330  1968  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     29
# 331  1969  Violent Crime  Murder and nonnegligent Manslaughter  Alaska     30

# %%
st = crimenes[crimenes.State == "Pennsylvania"]
st.head(10)
sns.boxplot(data=st, x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
st = crimenes[crimenes.State == "Nevada"]
st.head(10)
sns.boxplot(data=st, x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
# Out:
#    Year  Type of Crime                                 Crime    State  Count
# 0  1960  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    406
# 1  1961  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    427
# 2  1962  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 3  1963  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    340
# 4  1964  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 5  1965  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    395
# 6  1966  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    384
# 7  1967  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    415
# 8  1968  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    421
# 9  1969  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    485

# %%
st = crimenes[crimenes.State == "Alabama"]
st.head(10)
sns.boxplot(data=st, x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
# usar el criterio para extraer solo crimenes del crimen
cm = crimenes[crimenes.Crime == "Murder and nonnegligent Manslaughter"]

# %%
cm.head(10)
# Out:
#    Year  Type of Crime                                 Crime    State  Count
# 0  1960  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    406
# 1  1961  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    427
# 2  1962  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 3  1963  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    340
# 4  1964  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    316
# 5  1965  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    395
# 6  1966  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    384
# 7  1967  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    415
# 8  1968  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    421
# 9  1969  Violent Crime  Murder and nonnegligent Manslaughter  Alabama    485

# %%
# box plot
cm.boxplot(column='Year');

# %%
sns.boxplot(data=cm,  x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Forcible rape"]
cm.head(10)
sns.boxplot(data=cm,  x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Robbery"]
cm.head(10)
sns.boxplot(data=cm,  x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Aggravated assault"]
cm.head(10)
sns.boxplot(data=cm,  x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Burglary"]
cm.head(10)
sns.boxplot(data=cm,  x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Larceny-theft"]
cm.head(10)
sns.boxplot(data=cm, x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
cm = crimenes[crimenes.Crime == "Motor vehicle theft"]
cm.head(10)
sns.boxplot(data=cm, x='Year', y='Count')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>
